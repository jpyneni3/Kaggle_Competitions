# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn.ensemble
import sklearn.preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import seaborn as sns

# %%
#Read in data
data = pd.read_csv('../train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Remove attributes that are presumed irrelevant and see data
data.drop("PassengerId", axis=1, inplace=True)
data.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# Graphic view of data

# %%
# specifies the parameters of our graphs
fig = plt.figure(figsize=(18,6), dpi=1600) 
alpha=alpha_scatterplot = 0.2 
alpha_bar_chart = 0.55

# lets us plot many diffrent shaped graphs together 
ax1 = plt.subplot2grid((2,3),(0,0))
# plots a bar graph of those who surived vs those who did not.               
data.Survived.value_counts().plot(kind='bar', alpha=alpha_bar_chart)
# this nicely sets the margins in matplotlib to deal with a recent bug 1.3.1
ax1.set_xlim(-1, 2)
# puts a title on our graph
plt.title("Distribution of Survival, (1 = Survived)")
# Out:
# Text(0.5,1,'Distribution of Survival, (1 = Survived)')

# %% [markdown]
# This shows that most people did not survive. I want to see class distribution next

# %%
ax3 = plt.subplot2grid((2,3),(0,2))
data.Pclass.value_counts().plot(kind="barh", alpha=alpha_bar_chart)
ax3.set_ylim(-1, len(data.Pclass.value_counts()))
plt.title("Class Distribution")
# Out:
# Text(0.5,1,'Class Distribution')

# %%
#One hot encode sex
data['Sex'] = LabelEncoder().fit_transform(data['Sex'])

#Actual name does not matter but title might so replace name with just title
data['Name'] = data['Name'].map(lambda x: x.split(',')[1].split('.')[0].strip())
title_array = data["Name"].unique()
title_array
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer'], dtype=object)

# %%
#Fill missing ages with -1
data["Age"].fillna(-1, inplace= True)

medians = dict()
#Get the median age per title
for i in title_array:
    median = data.Age[(data["Age"] != -1) & (data['Name'] == i)].median()
    medians[i] = median

data.head(20)
# Out:
#     Survived  Pclass    Name  Sex   Age  SibSp  Parch            Ticket  \
# 0          0       3      Mr    1  22.0      1      0         A/5 21171
# 1          1       1     Mrs    0  38.0      1      0          PC 17599
# 2          1       3    Miss    0  26.0      0      0  STON/O2. 3101282
# 3          1       1     Mrs    0  35.0      1      0            113803
# 4          0       3      Mr    1  35.0      0      0            373450
# 5          0       3      Mr    1  -1.0      0      0            330877
# 6          0       1      Mr    1  54.0      0      0             17463
# 7          0       3  Master    1   2.0      3      1            349909
# 8          1       3     Mrs    0  27.0      0      2            347742
# 9          1       2     Mrs    0  14.0      1      0            237736
# 10         1       3    Miss    0   4.0      1      1           PP 9549
# 11         1       1    Miss    0  58.0      0      0            113783
# ...

# %%
#Replace missing age with median age of that title
for index, row in data.iterrows():
    if row["Age"] == -1:
        data.loc[index, "Age"] = medians[row["Name"]]
        
data.head(20)
# Out:
#     Survived  Pclass    Name  Sex   Age  SibSp  Parch            Ticket  \
# 0          0       3      Mr    1  22.0      1      0         A/5 21171
# 1          1       1     Mrs    0  38.0      1      0          PC 17599
# 2          1       3    Miss    0  26.0      0      0  STON/O2. 3101282
# 3          1       1     Mrs    0  35.0      1      0            113803
# 4          0       3      Mr    1  35.0      0      0            373450
# 5          0       3      Mr    1  30.0      0      0            330877
# 6          0       1      Mr    1  54.0      0      0             17463
# 7          0       3  Master    1   2.0      3      1            349909
# 8          1       3     Mrs    0  27.0      0      2            347742
# 9          1       2     Mrs    0  14.0      1      0            237736
# 10         1       3    Miss    0   4.0      1      1           PP 9549
# 11         1       1    Miss    0  58.0      0      0            113783
# ...

# %%
#Plot survived and not per title
fig = plt.figure(figsize=(15,6))

i=1
for title in data['Name'].unique():
    fig.add_subplot(3, 6, i)
    plt.title('Title : {}'.format(title))
    data.Survived[data['Name'] == title].value_counts().plot(kind='pie')
    i += 1

# %%
#Replace Name with numbers based upon survival
#If no one survived with that title = 0
#If everyone survived with that title = 7
#And then everything relative within

replacement = {
    'Don': 0,
    'Rev': 0,
    'Jonkheer': 0,
    'Capt': 0,
    'Mr': 1,
    'Dr': 2,
    'Col': 3,
    'Major': 3,
    'Master': 4,
    'Miss': 5,
    'Mrs': 6,
    'Mme': 7,
    'Ms': 7,
    'Mlle': 7,
    'Sir': 7,
    'Lady': 7,
    'the Countess': 7
}

data['Name'] = data['Name'].apply(lambda x: replacement.get(x))
data['Name'].value_counts()
# Out:
# 1    517
# 5    182
# 6    125
# 4     40
# 0      9
# 7      7
# 2      7
# 3      4
# Name: Name, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
data['Name'] = StandardScaler().fit_transform(data['Name'].values.reshape(-1, 1))
data.head()
# Out:
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
#    Survived  Pclass      Name  Sex   Age  SibSp  Parch            Ticket  \
# 0         0       3 -0.797294    1  22.0      1      0         A/5 21171
# 1         1       1  1.537975    0  38.0      1      0          PC 17599
# 2         1       3  1.070922    0  26.0      0      0  STON/O2. 3101282
# 3         1       1  1.537975    0  35.0      1      0            113803
# 4         0       3 -0.797294    1  35.0      0      0            373450
#
#       Fare Cabin Embarked
# 0   7.2500   NaN        S
# 1  71.2833   C85        C
# ...

# %%
#Scale age down as well because large numbers make a difference for sensitive classifiers
data['Age'] = StandardScaler().fit_transform(data['Age'].values.reshape(-1, 1))
data.head()
# Out:
#    Survived  Pclass      Name  Sex       Age  SibSp  Parch            Ticket  \
# 0         0       3 -0.797294    1 -0.557420      1      0         A/5 21171
# 1         1       1  1.537975    0  0.649410      1      0          PC 17599
# 2         1       3  1.070922    0 -0.255712      0      0  STON/O2. 3101282
# 3         1       1  1.537975    0  0.423129      1      0            113803
# 4         0       3 -0.797294    1  0.423129      0      0            373450
#
#       Fare Cabin Embarked
# 0   7.2500   NaN        S
# 1  71.2833   C85        C
# 2   7.9250   NaN        S
# 3  53.1000  C123        S
# 4   8.0500   NaN        S

# %%
#Similar approach for missing Fare Values
#Get the median Fare for that Pclass and replace missing value
data["Fare"].fillna(-1, inplace=True)
medians = dict()
for pclass in data['Pclass'].unique():
    median = data.Fare[(data["Fare"] != -1) & (data['Pclass'] == pclass)].median()
    medians[pclass] = median
for index, row in data.iterrows():
    if row['Fare'] == -1:
        data.loc[index, 'Fare'] = medians[row['Pclass']]
data['Fare'] = StandardScaler().fit_transform(data['Fare'].values.reshape(-1, 1))

# %%
fig = plt.figure(figsize=(15,4))

i=1
for pclass in data['Pclass'].unique():
    fig.add_subplot(1, 3, i)
    plt.title('Class : {}'.format(pclass))
    data.Survived[data['Pclass'] == pclass].value_counts().plot(kind='pie')
    i += 1

# %%
#Scale Pclass
data['Pclass'] = StandardScaler().fit_transform(data['Pclass'].values.reshape(-1, 1))
#Visual parent/child ratio survival rate
fig = plt.figure(figsize=(15,8))
i = 0
for parch in data['Parch'].unique():
    fig.add_subplot(2, 4, i+1)
    plt.title('Parents / Child : {}'.format(parch))
    data.Survived[data['Parch'] == parch].value_counts().plot(kind='pie')
    i += 1
# Out:
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
#Similar replacement as above and scale down 
replacement = {
    6: 0,
    4: 0,
    5: 1,
    0: 2,
    2: 3,
    1: 4,
    3: 5
}
data['Parch'] = data['Parch'].apply(lambda x: replacement.get(x))
data['Parch'] = StandardScaler().fit_transform(data['Parch'].values.reshape(-1, 1))
# Out:
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
#Drop ticket as we are considering it unnecessary
data.drop('Ticket', axis=1, inplace=True)
data['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
#Replace missing with 'S' (majority)
data['Embarked'].fillna('S', inplace=True)
fig = plt.figure(figsize=(15,4))
i = 1
#Visualize survival based upon class
for embarked in data['Embarked'].unique():
    fig.add_subplot(1, 3, i)
    plt.title('Embarked : {}'.format(embarked))
    data.Survived[data['Embarked'] == embarked].value_counts().plot(kind='pie')
    i += 1

# %%
replacement = {
    'S': 0, #Has more zeros
    'Q': 1,
    'C': 2 #Has least zeros
}
#Proportionate to embarked survival rates
#Apply lambda and scale
data['Embarked'] = data['Embarked'].apply(lambda x: replacement.get(x))
data['Embarked'] = StandardScaler().fit_transform(data['Embarked'].values.reshape(-1, 1))
data.head()['Embarked']
# Out:
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 0   -0.585954
# 1    1.942303
# 2   -0.585954
# 3   -0.585954
# 4   -0.585954
# Name: Embarked, dtype: float64

# %%
#Visualize sibling/spouse ratio vs survival
data['SibSp'].unique()
fig = plt.figure(figsize=(15,8))
i = 1
for sibsp in data['SibSp'].unique():
    fig.add_subplot(2, 4, i)
    plt.title('SibSp : {}'.format(sibsp))
    data.Survived[data['SibSp'] == sibsp].value_counts().plot(kind='pie')
    i += 1

# %%
#proportionate replacement
replacement = {
    5: 0, #All were 0
    8: 0,
    4: 1,
    3: 2,
    0: 3,
    2: 4,
    1: 5 #Lowest zero count
}

data['SibSp'] = data['SibSp'].apply(lambda x: replacement.get(x))
data['SibSp'] = StandardScaler().fit_transform(data['SibSp'].values.reshape(-1, 1))
data.head()['SibSp']
# Out:
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 0    1.576109
# 1    1.576109
# 2   -0.396241
# 3    1.576109
# 4   -0.396241
# Name: SibSp, dtype: float64

# %%
data['Cabin'].value_counts()
# Out:
# B96 B98            4
# G6                 4
# C23 C25 C27        4
# F33                3
# C22 C26            3
# E101               3
# D                  3
# F2                 3
# B51 B53 B55        2
# D33                2
# D35                2
# B20                2
# C93                2
# C125               2
# B77                2
# F4                 2
# C126               2
# F G73              2
# C2                 2
# B5                 2
# B35                2
# D17                2
# B57 B59 B63 B66    2
# B22                2
# D20                2
# E25                2
# C124               2
# C52                2
# E121               2
# C68                2
#                   ..
# E58                1
# B38                1
# A24                1
# C62 C64            1
# C118               1
# B50                1
# T                  1
# D30                1
# C32                1
# C104               1
# D37                1
# B30                1
# ...

# %%
#Replace NaNs with majority
data['Cabin'].fillna('U', inplace=True)
data['Cabin'] = data['Cabin'].apply(lambda x: x[0])
data['Cabin'].unique()
# Out:
# array(['U', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
#Visualize survival rates based on Cabin
fig = plt.figure(figsize=(15,12))
i = 1
for cabin in data['Cabin'].unique():
    fig.add_subplot(3, 3, i)
    plt.title('Cabin : {}'.format(cabin))
    data.Survived[data['Cabin'] == cabin].value_counts().plot(kind='pie')
    i += 1

# %%
#Replace accordingly and scale down
replacement = {
    'T': 0,
    'U': 1,
    'A': 2,
    'G': 3,
    'C': 4,
    'F': 5,
    'B': 6,
    'E': 7,
    'D': 8
}

data['Cabin'] = data['Cabin'].apply(lambda x: replacement.get(x))
data['Cabin'] = StandardScaler().fit_transform(data['Cabin'].values.reshape(-1, 1))
data.head()['Cabin']
# Out:
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 0   -0.494813
# 1    0.960231
# 2   -0.494813
# 3    0.960231
# 4   -0.494813
# Name: Cabin, dtype: float64

# %%
#Split into training and testing sets
(train_data, test_data) = train_test_split(data, test_size=0.1, random_state=67854895) 

x_train = train_data.drop('Survived', axis=1)
y_train = train_data['Survived']

x_test = test_data.drop('Survived', axis=1)
y_test = test_data['Survived']

# %%
#Returns the classifier's accuracy
def accuracy(classifier) -> float:
    num_correct = 0
    for i in range(len(x_test)):
        pred = classifier.predict([x_test.values[i]])[0]
        correct = y_test.values[i]
        if pred == correct:
                num_correct += 1
    return num_correct / len(x_test)

#Function that returns the false positive and false negative rate of a classifier
def false_rates(classifier) -> (float, float):
    num_negative = 0
    incorrect_negative = 0
    num_positive = 0
    incorrect_positive = 0
    for i in range(len(x_test)):
        pred = classifier.predict([x_test.values[i]])[0]
        correct = y_test.values[i]
        if correct == 0:
            num_negative += 1
            if pred != correct:
                incorrect_negative += 1
        else:
            num_positive += 1
            if pred != correct:
                incorrect_positive += 1
    fp = 0
    if num_negative != 0:
        fp = incorrect_negative / num_negative
    fn = 0
    if num_positive != 0:
        fn = incorrect_positive / num_positive
    return (fp, fn)

# %%
classifier =  KNeighborsClassifier(n_neighbors=8, weights='distance')
classifier.fit(x_train, y_train)
print(false_rates(classifier))
print(accuracy(classifier))
# Out:
# (0.1, 0.2)
# 0.8666666666666667

# %%
test_data = pd.read_csv('../test.csv')
#Remove attributes that are presumed irrelevant and see data
test_data.drop("PassengerId", axis=1, inplace=True)

# %%
test_data['Sex'] = LabelEncoder().fit_transform(test_data['Sex'])

#Actual name does not matter but title might so replace name with just title
test_data['Name'] = test_data['Name'].map(lambda x: x.split(',')[1].split('.')[0].strip())
title_array = test_data["Name"].unique()

#Fill missing ages with -1
test_data["Age"].fillna(-1, inplace= True)

medians = dict()
#Get the median age per title
for i in title_array:
    median = test_data.Age[(test_data["Age"] != -1) & (test_data['Name'] == i)].median()
    medians[i] = median

       
#Replace missing age with median age of that title
for index, row in test_data.iterrows():
    if row["Age"] == -1:
        test_data.loc[index, "Age"] = medians[row["Name"]]
#Replace null ages with mean age
test_data["Age"] = test_data["Age"].fillna(value=test_data["Age"].mean())

# %%
                                 
replacement = {
    'Don': 0,
    'Dona' : 0, #arbitrary
    'Rev': 0,
    'Jonkheer': 0,
    'Capt': 0,
    'Mr': 1,
    'Dr': 2,
    'Col': 3,
    'Major': 3,
    'Master': 4,
    'Miss': 5,
    'Mrs': 6,
    'Mme': 7,
    'Ms': 7,
    'Mlle': 7,
    'Sir': 7,
    'Lady': 7,
    'the Countess': 7
}
test_data['Name'] = test_data['Name'].apply(lambda x: replacement.get(x))
test_data["Name"].value_counts()
# Out:
# 1    240
# 5     78
# 6     72
# 4     21
# 0      3
# 3      2
# 7      1
# 2      1
# Name: Name, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
test_data['Name'] = StandardScaler().fit_transform(test_data['Name'].values.reshape(-1, 1))
# Out:
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
#Scale age down as well because large numbers make a difference for sensitive classifiers
test_data['Age'] = StandardScaler().fit_transform(test_data['Age'].values.reshape(-1, 1))

# %%
#Similar approach for missing Fare Values
#Get the median Fare for that Pclass and replace missing value
test_data["Fare"].fillna(-1, inplace=True)
medians = dict()
for pclass in test_data['Pclass'].unique():
    median = test_data.Fare[(data["Fare"] != -1) & (test_data['Pclass'] == pclass)].median()
    medians[pclass] = median
for index, row in test_data.iterrows():
    if row['Fare'] == -1:
        test_data.loc[index, 'Fare'] = medians[row['Pclass']]
test_data['Fare'] = StandardScaler().fit_transform(test_data['Fare'].values.reshape(-1, 1))

# %%
#Scale Pclass
test_data['Pclass'] = StandardScaler().fit_transform(test_data['Pclass'].values.reshape(-1, 1))

#Similar replacement as above and scale down 
replacement = {
    6: 0,
    4: 0,
    5: 1,
    0: 2,
    2: 3,
    1: 4,
    3: 5
}

for i in test_data['Parch'].value_counts().keys():
    if i not in list(replacement.keys()):
        replacement[i] = np.median(list(replacement.values()))
# Out:
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
test_data['Parch'] = test_data['Parch'].apply(lambda x: replacement.get(x))
test_data['Parch'] = StandardScaler().fit_transform(test_data['Parch'].values.reshape(-1, 1))
test_data.drop('Ticket', axis=1, inplace=True)

replacement = {
    'S': 0,
    'Q': 1,
    'C': 2
}

# %%
test_data['Embarked'] = test_data['Embarked'].apply(lambda x: replacement.get(x))
test_data['Embarked'] = StandardScaler().fit_transform(test_data['Embarked'].values.reshape(-1, 1))
# Out:
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
replacement = {
    5: 0,
    8: 0,
    4: 1,
    3: 2,
    0: 3,
    2: 4,
    1: 5
}

test_data['SibSp'] = test_data['SibSp'].apply(lambda x: replacement.get(x))
test_data['SibSp'] = StandardScaler().fit_transform(test_data['SibSp'].values.reshape(-1, 1))

test_data['Cabin'].fillna('U', inplace=True)
test_data['Cabin'] = test_data['Cabin'].apply(lambda x: x[0])
# Out:
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
replacement  = {
    'T': 0,
    'U': 1,
    'A': 2,
    'G': 3,
    'C': 4,
    'F': 5,
    'B': 6,
    'E': 7,
    'D': 8
}

test_data['Cabin'] = test_data['Cabin'].apply(lambda x: replacement.get(x))
test_data['Cabin'] = StandardScaler().fit_transform(test_data['Cabin'].values.reshape(-1, 1))
# Out:
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/jpyneni/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
output = [{'PassengerId' : 892 + i, 'Survived' : classifier.predict([test_data.values[i]])[0]} for i in range(len(test_data))]
pd.DataFrame(output).to_csv(path_or_buf='Analysis_Learner.csv', index=False)
